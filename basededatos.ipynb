# %%
import pandas as pd
import numpy as np 
import json
import statistics

# %%
#Load json 'notas_de_vejez_Wed, 15 Mar 2023 01_53 PM.json'
with open('notas_de_vejez_Wed, 15 Mar 2023 01_53 PM.json') as f:
    df = json.load(f)
#in this list of list extract name email nucelo and score
df = pd.DataFrame(df)
# iterate over the calificacion columns and extract the scores

# extract the required columns
result = df[['name', 'email', 'materia']]
for i in range(30):
    try:
        col_name = f'calificacion{i}'
        scores = []
        nucleos = []
        for row in df[col_name]:
            if row:
                for item in row:
                    if f'score{i}' in item:
                        scores.append(item[f'score{i}'])
                    if f'nucleo{i}' in item:
                        nucleos.append(item[f'nucleo{i}'])
        if len(scores) == len(result.index):
            try:
                result[f'score{i}'] = scores
            except ValueError:
                print("Length of scores exceeds length of index")
                pass
        elif len(scores) < len(result.index):
            try:
                scores += [None] * (len(result.index) - len(scores))
                result[f'score{i}'] = scores
            except ValueError:
                print("Length of scores exceeds length of index")
                pass
        else:
            raise ValueError("Length of scores exceeds length of index")
        
        if len(nucleos) == len(result.index):
            try:
                result[f'nucleo{i}'] = nucleos
            except ValueError:
                print("Length of nucleos exceeds length of index")
                pass
        elif len(nucleos) < len(result.index):
            try:
                nucleos += [None] * (len(result.index) - len(nucleos))
                result[f'nucleo{i}'] = nucleos
            except ValueError:
                print("Length of nucleos exceeds length of index")
                pass
        else:
            raise ValueError("Length of nucleos exceeds length of index")
    except:
        pass

result
# Out:
# /var/folders/jz/pl8ts8v13qj63tn3vn89bk3h0000gn/T/ipykernel_10041/3240268291.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result[f'score{i}'] = scores
# /var/folders/jz/pl8ts8v13qj63tn3vn89bk3h0000gn/T/ipykernel_10041/3240268291.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result[f'nucleo{i}'] = nucleos
# /var/folders/jz/pl8ts8v13qj63tn3vn89bk3h0000gn/T/ipykernel_10041/3240268291.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result[f'score{i}'] = scores
# /var/folders/jz/pl8ts8v13qj63tn3vn89bk3h0000gn/T/ipykernel_10041/3240268291.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result[f'nucleo{i}'] = nucleos
# /var/folders/jz/pl8ts8v13qj63tn3vn89bk3h0000gn/T/ipykernel_10041/3240268291.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result[f'score{i}'] = scores
# /var/folders/jz/pl8ts8v13qj63tn3vn89bk3h0000gn/T/ipykernel_10041/3240268291.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result[f'nucleo{i}'] = nucleos
# /var/folders/jz/pl8ts8v13qj63tn3vn89bk3h0000gn/T/ipykernel_10041/3240268291.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result[f'score{i}'] = scores
# /var/folders/jz/pl8ts8v13qj63tn3vn89bk3h0000gn/T/ipykernel_10041/3240268291.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result[f'nucleo{i}'] = nucleos
# /var/folders/jz/pl8ts8v13qj63tn3vn89bk3h0000gn/T/ipykernel_10041/3240268291.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result[f'score{i}'] = scores
# /var/folders/jz/pl8ts8v13qj63tn3vn89bk3h0000gn/T/ipykernel_10041/3240268291.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result[f'nucleo{i}'] = nucleos
# /var/folders/jz/pl8ts8v13qj63tn3vn89bk3h0000gn/T/ipykernel_10041/3240268291.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result[f'score{i}'] = scores
# /var/folders/jz/pl8ts8v13qj63tn3vn89bk3h0000gn/T/ipykernel_10041/3240268291.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result[f'nucleo{i}'] = nucleos
# /var/folders/jz/pl8ts8v13qj63tn3vn89bk3h0000gn/T/ipykernel_10041/3240268291.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result[f'score{i}'] = scores
# /var/folders/jz/pl8ts8v13qj63tn3vn89bk3h0000gn/T/ipykernel_10041/3240268291.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result[f'nucleo{i}'] = nucleos
# /var/folders/jz/pl8ts8v13qj63tn3vn89bk3h0000gn/T/ipykernel_10041/3240268291.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result[f'score{i}'] = scores
# /var/folders/jz/pl8ts8v13qj63tn3vn89bk3h0000gn/T/ipykernel_10041/3240268291.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result[f'nucleo{i}'] = nucleos
# /var/folders/jz/pl8ts8v13qj63tn3vn89bk3h0000gn/T/ipykernel_10041/3240268291.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result[f'score{i}'] = scores
#                                name                         email materia  \
# 0            TOBÓN_ORREGO_SANTIAGO_   santiago.tobono@udea.edu.co   vejez
# 1       RHENALS_SEPÚLVEDA_JUAN_JOSÉ      juan.rhenals@udea.edu.co   vejez
# 2      SOTO_PALACIOS_SARA_VALENTINA         sara.soto@udea.edu.co   vejez
# 3           BOTERO_GERENA_SANTIAGO_  santiago.botero2@udea.edu.co   vejez
# 4            AGUIRRE_RUEDA_MELISSA_   melissa.aguirre@udea.edu.co   vejez
# ..                              ...                           ...     ...
# 93      RUIZ_ZAMBRANO_GERMAN_DANIEL       german.ruiz@udea.edu.co   vejez
# 94  ORJUELA_ORTIZ_JENIFER_ESTEFANIA   jenifer.orjuela@udea.edu.co   vejez
# 95           RESTREPO_GÓMEZ_KARINA_  karina.restrepog@udea.edu.co   vejez
# 96        RUIZ_JIMENEZ_MARIA_CAMILA       maria.ruiz7@udea.edu.co   vejez
# 97          MADRID_GARCÍA_GEOVANNI_   geovanni.madrid@udea.edu.co   vejez
#
#     score0                              nucleo0  score1  \
# 0     4.50                           Living lab    4.00
# 1     4.38                           Living lab    4.50
# 2     5.00  Atención domiciliaria (ambulatoria)    4.80
# 3     5.00                Rotación Hospitalaria    4.32
# 4     5.00                Rotación Hospitalaria    5.00
# ..     ...                                  ...     ...
# 93    5.00                Rotación Hospitalaria    4.84
# 94    4.64                     Consulta externa    4.30
# 95    4.88                           Living lab    4.60
# 96    4.48                Rotación Hospitalaria    5.00
# 97     NaN                                 None     NaN
#
#                                 nucleo1  score2  \
# 0                 Rotación Hospitalaria    5.00
# 1                                cancer    4.32
# 2                            Living lab    4.74
# 3                 Rotación Hospitalaria    5.00
# 4                 Rotación Hospitalaria    4.38
# ..                                  ...     ...
# 93                Rotación Hospitalaria    4.52
# 94                           Living lab    4.80
# 95  Atención domiciliaria (ambulatoria)    4.84
# 96                Rotación Hospitalaria    4.32
# 97                                 None     NaN
#
#                                 nucleo2  score3  ... score11  \
# 0                 Rotación Hospitalaria    4.50  ...    4.96
# 1   Atención domiciliaria (ambulatoria)    4.72  ...    4.00
# 2                      Consulta externa    5.00  ...    4.60
# 3                 Rotación Hospitalaria    5.00  ...    5.00
# 4                 Rotación Hospitalaria    5.00  ...    4.92
# ..                                  ...     ...  ...     ...
# 93                Rotación Hospitalaria    4.60  ...     NaN
# 94  Atención domiciliaria (ambulatoria)    3.50  ...     NaN
# 95                     Consulta externa    5.00  ...     NaN
# 96                Rotación Hospitalaria    4.80  ...     NaN
# 97                                 None     NaN  ...     NaN
#
#                                nucleo11 score12               nucleo12  \
# 0                 Rotación Hospitalaria    5.00  Rotación Hospitalaria
# 1   Atención domiciliaria (ambulatoria)    3.62       Consulta externa
# 2                                cancer    4.60             Living lab
# 3                      Consulta externa    5.00  Rotación Hospitalaria
# 4                 Rotación Hospitalaria    4.54             Living lab
# ..                                  ...     ...                    ...
# 93                                 None     NaN                   None
# 94                                 None     NaN                   None
# 95                                 None     NaN                   None
# 96                                 None     NaN                   None
# 97                                 None     NaN                   None
#
#    score13                             nucleo13 score14  \
# 0     5.00                Rotación Hospitalaria    5.00
# 1     4.28                               cancer    4.82
# 2     5.00                Rotación Hospitalaria    5.00
# 3     5.00                               cancer    4.92
# 4     5.00  Atención domiciliaria (ambulatoria)     NaN
# ..     ...                                  ...     ...
# 93     NaN                                 None     NaN
# 94     NaN                                 None     NaN
# 95     NaN                                 None     NaN
# 96     NaN                                 None     NaN
# 97     NaN                                 None     NaN
#
#                  nucleo14 score15          nucleo15
# 0   Rotación Hospitalaria    4.52        Living lab
# 1        Consulta externa    5.00  Consulta externa
# 2        Consulta externa     NaN              None
# 3   Rotación Hospitalaria     NaN              None
# 4                    None     NaN              None
# ..                    ...     ...               ...
# 93                   None     NaN              None
# 94                   None     NaN              None
# 95                   None     NaN              None
# 96                   None     NaN              None
# 97                   None     NaN              None
#
# [98 rows x 35 columns]

# %%
result.to_excel('notas_de_vejez_Wed, 15 Mar 2023 01_53 PM.xlsx', index=False
                )
